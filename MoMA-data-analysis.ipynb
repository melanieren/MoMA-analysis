# %% [markdown]
# # Exploratory Data Analysis of Artists and Artworks at the MoMA

# %% [markdown]
# ### Import libraries and artwork data

# %%
import numpy as np
import pandas as pd

# %%
artworks = pd.read_csv('data/artworks.csv')

# %%
artworks.shape
# Out:
# (130262, 21)

# %%
artworks.head()
# Out:
#    Artwork ID                                              Title Artist ID  \
# 0           2  Ferdinandsbrücke Project, Vienna, Austria, Ele...      6210
# 1           3  City of Music, National Superior Conservatory ...      7470
# 2           4  Villa near Vienna Project, Outside Vienna, Aus...      7605
# 3           5  The Manhattan Transcripts Project, New York, N...      7056
# 4           6  Villa, project, outside Vienna, Austria, Exter...      7605
#
#                        Name  Date  \
# 0               Otto Wagner  1896
# 1  Christian de Portzamparc  1987
# 2                Emil Hoppe  1903
# 3           Bernard Tschumi  1980
# 4                Emil Hoppe  1903
#
#                                               Medium  \
# 0      Ink and cut-and-pasted painted pages on paper
# 1                  Paint and colored pencil on print
# 2  Graphite, pen, color pencil, ink, and gouache ...
# 3  Photographic reproduction with colored synthet...
# 4  Graphite, color pencil, ink, and gouache on tr...
#
#                            Dimensions Acquisition Date  \
# 0  19 1/8 x 66 1/2" (48.6 x 168.9 cm)       1996-04-09
# 1       16 x 11 3/4" (40.6 x 29.8 cm)       1995-01-17
# 2   13 1/2 x 12 1/2" (34.3 x 31.8 cm)       1997-01-15
# 3           20 x 20" (50.8 x 50.8 cm)       1995-01-17
# 4    15 1/8 x 7 1/2" (38.4 x 19.1 cm)       1997-01-15
#
#                                               Credit Catalogue      ...       \
# 0  Fractional and promised gift of Jo Carole and ...         Y      ...
# 1  Gift of the architect in honor of Lily Auchinc...         Y      ...
# 2             Gift of Jo Carole and Ronald S. Lauder         Y      ...
# 3  Purchase and partial gift of the architect in ...         Y      ...
# 4             Gift of Jo Carole and Ronald S. Lauder         Y      ...
#
#   Classification Object Number Diameter (cm)  Circumference (cm)  Height (cm)  \
# 0   Architecture      885.1996           NaN                 NaN      48.6000
# 1   Architecture        1.1995           NaN                 NaN      40.6401
# 2   Architecture        1.1997           NaN                 NaN      34.3000
# 3   Architecture        2.1995           NaN                 NaN      50.8000
# 4   Architecture        2.1997           NaN                 NaN      38.4000
#
#    Length (cm)  Width (cm)  Depth (cm)  Weight (kg)  Duration (s)
# 0          NaN    168.9000         NaN          NaN           NaN
# 1          NaN     29.8451         NaN          NaN           NaN
# 2          NaN     31.8000         NaN          NaN           NaN
# 3          NaN     50.8000         NaN          NaN           NaN
# 4          NaN     19.1000         NaN          NaN           NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# ## 1. Artists with the most pieces on display

# %% [markdown]
# ### Count the number of pieces each artist has on display and show the top 10 artists

# %%
df_artworks = pd.DataFrame(artworks)

# %%
df_artworks['Name'].value_counts().head(20)
# Out:
# Eugène Atget                5050
# Louise Bourgeois            3318
# Ludwig Mies van der Rohe    2566
# Unknown photographer        1575
# Jean Dubuffet               1435
# Lee Friedlander             1317
# Pablo Picasso               1310
# Marc Chagall                1162
# Henri Matisse               1063
# Pierre Bonnard               894
# Lilly Reich                  823
# Frank Lloyd Wright           799
# George Maciunas              762
# August Sander                749
# Unknown Artist               680
# Georges Rouault              632
# Émile Bernard                631
# Ben Kinmont                  597
# Aristide Maillol             579
# André Derain                 573
# Name: Name, dtype: int64

# %% [markdown]
# ### Use matplotlib to create a bar graph to display the 20 artists with the most pieces on display

# %%
import matplotlib.pyplot as plt

# %%
top_10_artists = df_artworks['Name'].value_counts()[:20]

# %%
top_10_artists.plot(kind='barh').invert_yaxis()
plt.ylabel('Artist') 
plt.xlabel('Number of Pieces on Display')
plt.suptitle('Artists With the Most Pieces on Display at the MoMA', fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# ## 2. Proportion of male to female artists with pieces on display

# %% [markdown]
# ### Import artist data

# %%
artists = pd.read_csv('data/artists.csv')

# %%
artists.shape
# Out:
# (15091, 6)

# %%
artists.head()
# Out:
#    Artist ID             Name Nationality Gender  Birth Year  Death Year
# 0          1   Robert Arneson    American   Male      1930.0      1992.0
# 1          2   Doroteo Arnaiz     Spanish   Male      1936.0         NaN
# 2          3      Bill Arnold    American   Male      1941.0         NaN
# 3          4  Charles Arnoldi    American   Male      1946.0         NaN
# 4          5      Per Arnoldi      Danish   Male      1941.0         NaN

# %%
df_artists = pd.DataFrame(artists)

# %% [markdown]
# ### Find the proportion of male to female artists who have works on display at the MoMA

# %%
df_artists['Gender'].value_counts()
# Out:
# Male      9820
# Female    2193
# male         6
# Name: Gender, dtype: int64

# %% [markdown]
# ### Clean up missing values and capitalization inconsistencies in the artist data

# %%
df_artists['Gender'].replace('male', 'Male',inplace=True)
df_artists['Gender'].replace(np.nan, 'Unknown', inplace=True)

# %% [markdown]
# ### Check that all artists have been accounted for

# %%
df['Gender'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-d91d5b35f115> in <module>()
# ----> 1 df['Gender'].value_counts()
#
# NameError: name 'df' is not defined

# %%
print(sum(df_artists['Gender'].value_counts()) == df_artists.shape[0])
# Out:
# True

# %%
df_artists
# Out:
#        Artist ID                   Name Nationality   Gender  Birth Year  \
# 0              1         Robert Arneson    American     Male      1930.0
# 1              2         Doroteo Arnaiz     Spanish     Male      1936.0
# 2              3            Bill Arnold    American     Male      1941.0
# 3              4        Charles Arnoldi    American     Male      1946.0
# 4              5            Per Arnoldi      Danish     Male      1941.0
# 5              6          Danilo Aroldi     Italian     Male      1925.0
# 6              7              Bill Aron    American     Male      1941.0
# 7              9          David Aronson    American     Male      1923.0
# 8             10          Irene Aronson    American   Female      1918.0
# 9             11        Jean (Hans) Arp      French     Male      1886.0
# 10            12             Jüri Arrak    Estonian     Male      1936.0
# 11            13    J. Arrelano Fischer     Mexican     Male      1911.0
# 12            15          Folke Arstrom     Swedish     Male      1907.0
# 13            16      Cristobal Arteche     Spanish     Male      1900.0
# 14            18                  Artko         NaN  Unknown         NaN
# 15            19    Richard Artschwager    American     Male      1923.0
# 16            21             Ruth Asawa    American   Female      1926.0
# 17            22       Isidora Aschheim     Israeli   Female         NaN
# 18            23  Charles Robert Ashbee     British     Male      1863.0
# 19            24        Donald Ashcraft    American     Male      1927.0
# 20            25             E. M. Ashe    American     Male      1867.0
# 21            26            Göran Åslin     Swedish  Unknown      1940.0
# 22            27    Erik Gunnar Asplund     Swedish     Male      1885.0
# 23            28         Geneviève Asse      French   Female      1923.0
# 24            30            Sergio Asti     Italian     Male      1926.0
# 25            31           Dana Atchley    American   Female      1941.0
# 26            32         Atelier Eggers      French  Unknown         NaN
# 27            33                 A.A.P.    American  Unknown         NaN
# 28            34            Alvar Aalto     Finnish     Male      1898.0
# 29            35             Aino Aalto     Finnish   Female      1894.0
# ...          ...                    ...         ...      ...         ...
# 15061      67323         Greta Schiller    American  Unknown      1954.0
# 15062      67325           Carlos Saura     Spanish  Unknown      1932.0
# 15063      67326            Tessie Chua    American  Unknown      1949.0
# 15064      67327           Alexa Hunter    American  Unknown      1957.0
# 15065      67328         Jonathan Quinn    American  Unknown      1956.0
# 15066      67329          Rudi Protrudi    American  Unknown      1952.0
# 15067      67330            Bill Harris    American  Unknown      1958.0
# 15068      67331           Anney Bonney    American  Unknown         NaN
# 15069      67332         Glenn Andreiev    American  Unknown      1961.0
# 15070      67333          Manfred Blank      German  Unknown      1949.0
# 15071      67334             Kevin Asch    American  Unknown      1975.0
# 15072      67336             Cal Dalton    American  Unknown      1908.0
# 15073      67337             Cal Howard    American  Unknown      1911.0
# 15074      67340         M. Henry Jones    American  Unknown      1957.0
# 15075      67342           Mannie Davis         NaN  Unknown         NaN
# 15076      67345            George Haas    American  Unknown      1953.0
# 15077      67346           Jimmy Murray         NaN  Unknown         NaN
# 15078      67349           Julius Klein    American  Unknown      1951.0
# 15079      67350      Howard Guttenplan    American  Unknown      1934.0
# 15080      67352        Neelon Crawford    American  Unknown      1946.0
# 15081      67353         Michael Mideke         NaN  Unknown         NaN
# 15082      67379                N. Dash    American   Female      1980.0
# 15083      67420  Walter Burley Griffin         NaN  Unknown         NaN
# 15084      67437        Sebastian Black    American     Male      1985.0
# 15085      67451                Xiao Yu     Chinese     Male      1965.0
# 15086      67452            Liu Jianhua     Chinese     Male      1962.0
# 15087      67453               Leng Lin     Chinese     Male      1965.0
# 15088      67652           Ellie Nagler         NaN  Unknown         NaN
# 15089      67694         Glenn Williams         NaN     Male         NaN
# 15090      67695              Ely Ramen         NaN  Unknown         NaN
#
#        Death Year
# 0          1992.0
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9          1966.0
# 10            NaN
# 11         1995.0
# 12         1997.0
# 13         1964.0
# 14            NaN
# 15         2013.0
# 16         2013.0
# 17            NaN
# 18         1942.0
# 19            NaN
# 20         1941.0
# 21            NaN
# 22         1940.0
# 23            NaN
# 24            NaN
# 25         2000.0
# 26            NaN
# 27            NaN
# 28         1976.0
# 29         1949.0
# ...           ...
# 15061         NaN
# 15062         NaN
# 15063         NaN
# 15064         NaN
# 15065         NaN
# 15066         NaN
# 15067         NaN
# 15068         NaN
# 15069         NaN
# 15070         NaN
# 15071         NaN
# 15072      1974.0
# 15073      1993.0
# 15074         NaN
# 15075         NaN
# 15076         NaN
# 15077         NaN
# 15078         NaN
# 15079      2015.0
# 15080         NaN
# 15081         NaN
# 15082         NaN
# 15083         NaN
# 15084         NaN
# 15085         NaN
# 15086         NaN
# 15087         NaN
# 15088         NaN
# 15089         NaN
# 15090         NaN
#
# [15091 rows x 6 columns]

# %% [markdown]
# ### Graph the proportion of male to female artists

# %%
labels = df_artists['Gender'].value_counts().index
sizes = df_artists['Gender'].value_counts().values
colors = ['gold', 'lightcoral', 'lightskyblue']

# Plot
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', shadow=False, startangle=140)
plt.axis('equal')
plt.suptitle('Artists with Pieces on Display at the MoMA', fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# ## 3. Artists by nationality
# ### Find the proportion of artists of each nationality

# %%
most_common_nationalities = df_artists['Nationality'].value_counts()[:20]
most_common_nationalities.plot(kind='barh').invert_yaxis()
plt.ylabel('Nationality') 
plt.xlabel('Number of Artists')
plt.suptitle('Most Common Nationalities of the Artists on Display at the MoMA', fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# ### Classify the 20 most common nationalities of the artists by continent

# %%
df_artists['Continent'] = np.nan

north_america = ['American', 'Canadian', 'Mexican']
south_america = ['Brazilian', 'Argentine']
europe = ['German', 'French', 'British', 'Italian', 'Swiss', 'Dutch', 'Austrian', 
            'Russian', 'Spanish', 'Polish', 'Danish', 'Belgian']
asia = ['Japanese']

def classify_nationality(row_index) :
    if df_artists.loc[row_index,'Nationality'] in north_america:
        df_artists.loc[row_index, 'Continent'] = 'North America'
    elif df_artists.loc[row_index,'Nationality'] in south_america:
        df_artists.loc[row_index, 'Continent'] = 'South America'
    elif df_artists.loc[row_index,'Nationality'] in europe:
        df_artists.loc[row_index, 'Continent'] = 'Europe'
    elif df_artists.loc[row_index,'Nationality'] in asia:
        df_artists.loc[row_index, 'Continent'] = 'Asia'
    elif (df_artists.loc[row_index,'Nationality'] == 'Nationality unknown') :
        df_artists.loc[row_index, 'Continent'] = 'Unknown'
            
for index, row in df_artists.iterrows() : 
    classify_nationality(index)

# %% [markdown]
# ### Graph the proportion of continents represented by the 20 most common nationalities of the artists at the MoMA

# %%
labels = df_artists['Continent'].value_counts().index
sizes = df_artists['Continent'].value_counts().values
colors = ['gold', 'lightcoral', 'lightskyblue', 'mediumslateblue', 'firebrick']
plt.pie(sizes, colors=colors, autopct='%1.1f%%', pctdistance=1.2, shadow=False, startangle=140)
plt.axis('equal')
plt.suptitle('Top 20 Most Common Artist Nationalities by Continent', fontsize=14, fontweight='bold')
plt.legend(labels,loc=4)
plt.show()

# %% [markdown]
# ## 4. When were the pieces on display added to the collection at MoMA?
# ### Sort the artworks data by 'Acquisition Date'

# %%
df_artworks['Acquisition Date'] = pd.to_datetime(df_artworks['Acquisition Date'], errors='coerce')
acquisitions = df_artworks['Acquisition Date'].value_counts()
acquisitions_sorted = acquisitions.sort_index()

# %% [markdown]
# ### Show the data as a time series

# %%
acquisitions_sorted_cumsum = acquisitions_sorted.cumsum()
ts = acquisitions_sorted_cumsum.plot()
ts.set_title('Total Number of Artworks Acquired by the MoMA Over Time', fontsize=14, fontweight='bold')
ts.set_xlabel("Year")
ts.set_ylabel("Total Number of Artworks Acquired")
# Out:
# Text(0,0.5,'Total Number of Artworks Acquired')
